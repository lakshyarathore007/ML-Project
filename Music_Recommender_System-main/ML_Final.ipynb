# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Dataset/spotify_millsongdata.csv')
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.tail(5)
# Out:
#              artist           song  \
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df=df.sample(7000).drop('link',axis=1).reset_index(drop=True)
df.head(10)
# Out:
#                artist                                song  \
# 0        Depeche Mode                               Alone
# 1        Richard Marx                     Touch Of Heaven
# 2       Hank Williams                   Singing Waterfall
# 3         Chris Brown                      All I Wanna Do
# 4  Christina Aguilera         These Are The Special Times
# 5        Bette Midler  What Are You Doing New Year's Eve?
# 6      Elvis Costello                              Bedlam
# 7       Pet Shop Boys                   New York City Boy
# 8       Guns N' Roses                  Jumping Jack Flash
# 9     Freddie Aguilar                          Sinasaktan
#
#                                                 text
# 0  I was there when you needed me most  \r\nI was...
# 1  Your eyes burn through me,  \r\nOh, like a rag...
# 2  There's a singing waterfall  \r\nIn the mounta...
# 3  Let the beat drop... (spoken)  \r\n  \r\nBoo.....
# 4  In these moments, moments of our lives  \r\nAl...
# 5  When the bells all ring and the horns all blow...
# 6  I've got this phosphorescent portrait of gentl...
# 7  When you're a boy  \r\nSome days are tough  \r...
# 8  I was born in a cross-fire hurricane  \r\nAnd ...
# 9  Ikaw pala lagi ang tama  \r\n'Di ka na ba matu...

# %%
df['text'][0]
# Out:
# "I was there when you needed me most  \r\nI was there when you wanted me least  \r\nI was your father, your son,  \r\nAnd your holy ghost and priest  \r\n  \r\nThrough your failures and success  \r\nThrough your losses and gains  \r\nI didn't see much happiness or pain  \r\n  \r\nI couldn't save your soul  \r\nI couldn't even take you home  \r\nI couldn't fill that hole  \r\nAlone  \r\n  \r\nI saw you at your best  \r\nI knew you at your worst  \r\nI couldn't tell if you were blessed or cursed  \r\n  \r\nThere's a thin grey line  \r\nBetween the black and white  \r\nIt's evidently hard to find at night  \r\n  \r\nI couldn't save your soul  \r\nI couldn't even take you home  \r\nI couldn't play that role  \r\nAlone  \r\n  \r\nNow it's too, too late for  \r\nwords That should have been said  \r\nLong ago  \r\n  \r\nI was there when you needed me most  \r\nI was there when you wanted me least  \r\nI was your father, your son,  \r\nAnd your holy ghost and priest  \r\n  \r\nI couldn't save your soul  \r\nI couldn't even take you home  \r\nI couldn't fill that hole  \r\nAlone\r\n\r\n"

# %%
df.shape
# Out:
# (7000, 3)

# %%
df['text'] = df['text'].str.lower().replace(r'^a\w\s','').replace(r'\n',' ', regex = True)

# %% [markdown]
# cosine similarities

# %%
df.tail(5)
# Out:
#               artist                       song  \
# 6995  Tragically Hip  At The Hundredth Meridian
# 6996     The Beatles                 For No One
# 6997     Tina Turner             It's Only Love
# 6998     Demi Lovato                      Trash
# 6999     Moody Blues              Twilight Time
#
#                                                    text
# 6995  me debunk an american myth?  \r and take my li...
# 6996  your day breaks, your mind aches  \r you find ...
# 6997  when the feeling is ended  \r there ain't no u...
# 6998  don't try to cover up your, your new flame  \r...
# 6999  twilight time to dream awhile,  \r in veils of...

# %%
import nltk
nltk.download('punkt')
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
stemmer = PorterStemmer()

# %%
def token(txt):
  token = nltk.word_tokenize(txt)
  a = [stemmer.stem(w) for w in token]
  return " ".join(a)

# %%
token("you are beautiful, beauty")
# Out:
# 'you are beauti , beauti'

# %%
df['text'].apply(lambda x: token(x))
# Out:
# 0       i wa there when you need me most i wa there wh...
# 1       your eye burn through me , oh , like a rage fi...
# 2       there 's a sing waterfal in the mountain far a...
# 3       let the beat drop ... ( spoken ) boo ... tell ...
# 4       in these moment , moment of our live all the w...
#                               ...
# 6995    me debunk an american myth ? and take my life ...
# 6996    your day break , your mind ach you find that a...
# 6997    when the feel is end there ai n't no use prete...
# 6998    do n't tri to cover up your , your new flame t...
# 6999    twilight time to dream awhil , in veil of deep...
# Name: text, Length: 7000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfid = TfidfVectorizer(analyzer ='word', stop_words ='english')

# %%
matrix=tfid.fit_transform(df['text'])

# %%
similar = cosine_similarity(matrix)

# %%
similar[0]
# Out:
# array([1.        , 0.06369188, 0.00358094, ..., 0.01270606, 0.01301322,
#        0.00260151])

# %%
df[df['song'] =='For No One'].index[0]
# Out:
# 6996

# %% [markdown]
# Recommender Function

# %%
def recommender(song_name):
  idx = df[df['song'] ==song_name].index[0]
  distance = sorted(list(enumerate(similar[idx])), reverse = True, key = lambda x:x[1])
  song = []
  for s_id in distance[0:21]:
    song.append(df.iloc[s_id[0]].song)
  return song

# %%
recommender("Touch Of Heaven")
# Out:
# ['Touch Of Heaven',
#  'I Surrender',
#  'Surrender',
#  'Take Me',
#  'I Surrender',
#  'Oh Baby',
#  'Touch It',
#  'Touch And Go',
#  'My One And Only Love',
#  'Let Me Love You',
#  'Oh! No Not My Baby',
#  'Who Is It?',
#  'My Baby',
#  'Shadows Of The Night',
#  'Cry Baby',
#  'Secret Love',
#  'Without You',
#  'Last Kiss',
#  'Moses',
#  'Do It To Me',
#  'The Way That You Love']

# %%
import pickle

# %%
pickle.dump(similar, open("similarity","wb"))
pickle.dump(df,open("df","wb"))
